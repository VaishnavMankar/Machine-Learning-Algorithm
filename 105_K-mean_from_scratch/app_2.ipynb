# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from kmeans import KMeans
import pandas as pd
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 3
#     from kmeans import KMeans
#
#   File E:\Python\CampusX\105_K-mean_from_scratch\kmeans.py:7
#     self.max_iter = max_it er
#                            ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('student_clustering.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('student_clustering.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
plt.scatter(df['cgpa'],df['iq'],c='blue',alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.scatter(df['cgpa'],df['iq'],c='blue',alpha=0.5)
#
# NameError: name 'df' is not defined

# %%
X = df.iloc[:,:].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X = df.iloc[:,:].values
#
# NameError: name 'df' is not defined

# %%
km = KMeans(n_clusters=4,max_iter=500)
y_means = km.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 km = KMeans(n_clusters=4,max_iter=500)
#       2 y_means = km.fit_predict(X)
#
# NameError: name 'KMeans' is not defined

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='red')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='blue')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='red')
#       2 plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='blue')
#       3 plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
#
# NameError: name 'X' is not defined
